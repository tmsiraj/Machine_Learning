# %%
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('./athlete_events.csv')

# %%
df
# Out:
#             ID                      Name Sex   Age  Height  Weight  \
# 0            1                 A Dijiang   M  24.0   180.0    80.0
# 1            2                  A Lamusi   M  23.0   170.0    60.0
# 2            3       Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3            4      Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 4            5  Christine Jacoba Aaftink   F  21.0   185.0    82.0
# ...        ...                       ...  ..   ...     ...     ...
# 271111  135569                Andrzej ya   M  29.0   179.0    89.0
# 271112  135570                  Piotr ya   M  27.0   176.0    59.0
# 271113  135570                  Piotr ya   M  27.0   176.0    59.0
# 271114  135571        Tomasz Ireneusz ya   M  30.0   185.0    96.0
# 271115  135571        Tomasz Ireneusz ya   M  34.0   185.0    96.0
#
#                   Team  NOC        Games  Year  Season            City  \
# 0                China  CHN  1992 Summer  1992  Summer       Barcelona
# ...

# %%
df.drop(columns=['ID','Games'], inplace=True)

# %%
df
# Out:
#                             Name Sex   Age  Height  Weight            Team  \
# 0                      A Dijiang   M  24.0   180.0    80.0           China
# 1                       A Lamusi   M  23.0   170.0    60.0           China
# 2            Gunnar Nielsen Aaby   M  24.0     NaN     NaN         Denmark
# 3           Edgar Lindenau Aabye   M  34.0     NaN     NaN  Denmark/Sweden
# 4       Christine Jacoba Aaftink   F  21.0   185.0    82.0     Netherlands
# ...                          ...  ..   ...     ...     ...             ...
# 271111                Andrzej ya   M  29.0   179.0    89.0        Poland-1
# 271112                  Piotr ya   M  27.0   176.0    59.0          Poland
# 271113                  Piotr ya   M  27.0   176.0    59.0          Poland
# 271114        Tomasz Ireneusz ya   M  30.0   185.0    96.0          Poland
# 271115        Tomasz Ireneusz ya   M  34.0   185.0    96.0          Poland
#
#         NOC  Year  Season            City          Sport  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 271116 entries, 0 to 271115
# Data columns (total 13 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Name    271116 non-null  object
#  1   Sex     271116 non-null  object
#  2   Age     261642 non-null  float64
#  3   Height  210945 non-null  float64
#  4   Weight  208241 non-null  float64
#  5   Team    271116 non-null  object
#  6   NOC     271116 non-null  object
#  7   Year    271116 non-null  int64
#  8   Season  271116 non-null  object
#  9   City    271116 non-null  object
#  10  Sport   271116 non-null  object
#  11  Event   271116 non-null  object
#  12  Medal   39783 non-null   object
# dtypes: float64(3), int64(1), object(9)
# memory usage: 26.9+ MB

# %%
df.Team.value_counts()
# Out:
# United States    17847
# France           11988
# Great Britain    11404
# Italy            10260
# Germany           9326
#                  ...
# Briar                1
# Hannover             1
# Nan-2                1
# Brentina             1
# Digby                1
# Name: Team, Length: 1184, dtype: int64

# %%
summer=df[df['Season']=='Summer']
summer
# Out:
#                                       Name Sex   Age  Height  Weight  \
# 0                                A Dijiang   M  24.0   180.0    80.0
# 1                                 A Lamusi   M  23.0   170.0    60.0
# 2                      Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3                     Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 26      Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
# ...                                    ...  ..   ...     ...     ...
# 271106            Fernando scar Zylberberg   M  27.0   168.0    76.0
# 271107          James Francis "Jim" Zylker   M  21.0   175.0    75.0
# 271108        Aleksandr Viktorovich Zyuzin   M  24.0   183.0    72.0
# 271109        Aleksandr Viktorovich Zyuzin   M  28.0   183.0    72.0
# 271110              Olga Igorevna Zyuzkova   F  33.0   171.0    69.0
#
#                   Team  NOC  Year  Season            City       Sport  \
# ...

# %%
summer.drop(columns=['Season'],inplace=True)
summer
# Out:
#                                       Name Sex   Age  Height  Weight  \
# 0                                A Dijiang   M  24.0   180.0    80.0
# 1                                 A Lamusi   M  23.0   170.0    60.0
# 2                      Gunnar Nielsen Aaby   M  24.0     NaN     NaN
# 3                     Edgar Lindenau Aabye   M  34.0     NaN     NaN
# 26      Cornelia "Cor" Aalten (-Strannood)   F  18.0   168.0     NaN
# ...                                    ...  ..   ...     ...     ...
# 271106            Fernando scar Zylberberg   M  27.0   168.0    76.0
# 271107          James Francis "Jim" Zylker   M  21.0   175.0    75.0
# 271108        Aleksandr Viktorovich Zyuzin   M  24.0   183.0    72.0
# 271109        Aleksandr Viktorovich Zyuzin   M  28.0   183.0    72.0
# 271110              Olga Igorevna Zyuzkova   F  33.0   171.0    69.0
#
#                   Team  NOC  Year            City       Sport  \
# 0                China  CHN  1992       Barcelona  Basketball
# ...

# %%
summer.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 222552 entries, 0 to 271110
# Data columns (total 12 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Name    222552 non-null  object
#  1   Sex     222552 non-null  object
#  2   Age     213363 non-null  float64
#  3   Height  170695 non-null  float64
#  4   Weight  168698 non-null  float64
#  5   Team    222552 non-null  object
#  6   NOC     222552 non-null  object
#  7   Year    222552 non-null  int64
#  8   City    222552 non-null  object
#  9   Sport   222552 non-null  object
#  10  Event   222552 non-null  object
#  11  Medal   34088 non-null   object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 22.1+ MB

# %%
winter=df[df['Season']=='Winter']
winter
# Out:
#                             Name Sex   Age  Height  Weight         Team  NOC  \
# 4       Christine Jacoba Aaftink   F  21.0   185.0    82.0  Netherlands  NED
# 5       Christine Jacoba Aaftink   F  21.0   185.0    82.0  Netherlands  NED
# 6       Christine Jacoba Aaftink   F  25.0   185.0    82.0  Netherlands  NED
# 7       Christine Jacoba Aaftink   F  25.0   185.0    82.0  Netherlands  NED
# 8       Christine Jacoba Aaftink   F  27.0   185.0    82.0  Netherlands  NED
# ...                          ...  ..   ...     ...     ...          ...  ...
# 271111                Andrzej ya   M  29.0   179.0    89.0     Poland-1  POL
# 271112                  Piotr ya   M  27.0   176.0    59.0       Poland  POL
# 271113                  Piotr ya   M  27.0   176.0    59.0       Poland  POL
# 271114        Tomasz Ireneusz ya   M  30.0   185.0    96.0       Poland  POL
# 271115        Tomasz Ireneusz ya   M  34.0   185.0    96.0       Poland  POL
#
# ...

# %%
winter.drop(columns=['Season'],inplace=True)
winter
# Out:
#                             Name Sex   Age  Height  Weight         Team  NOC  \
# 4       Christine Jacoba Aaftink   F  21.0   185.0    82.0  Netherlands  NED
# 5       Christine Jacoba Aaftink   F  21.0   185.0    82.0  Netherlands  NED
# 6       Christine Jacoba Aaftink   F  25.0   185.0    82.0  Netherlands  NED
# 7       Christine Jacoba Aaftink   F  25.0   185.0    82.0  Netherlands  NED
# 8       Christine Jacoba Aaftink   F  27.0   185.0    82.0  Netherlands  NED
# ...                          ...  ..   ...     ...     ...          ...  ...
# 271111                Andrzej ya   M  29.0   179.0    89.0     Poland-1  POL
# 271112                  Piotr ya   M  27.0   176.0    59.0       Poland  POL
# 271113                  Piotr ya   M  27.0   176.0    59.0       Poland  POL
# 271114        Tomasz Ireneusz ya   M  30.0   185.0    96.0       Poland  POL
# 271115        Tomasz Ireneusz ya   M  34.0   185.0    96.0       Poland  POL
#
# ...

# %%
winter.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 48564 entries, 4 to 271115
# Data columns (total 12 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    48564 non-null  object
#  1   Sex     48564 non-null  object
#  2   Age     48279 non-null  float64
#  3   Height  40250 non-null  float64
#  4   Weight  39543 non-null  float64
#  5   Team    48564 non-null  object
#  6   NOC     48564 non-null  object
#  7   Year    48564 non-null  int64
#  8   City    48564 non-null  object
#  9   Sport   48564 non-null  object
#  10  Event   48564 non-null  object
#  11  Medal   5695 non-null   object
# dtypes: float64(3), int64(1), object(8)
# memory usage: 4.8+ MB

# %% [markdown]
# ## Q1. Which country got most number of medal?

# %%
df.value_counts('NOC')
# Out:
# NOC
# USA    18853
# FRA    12758
# GBR    12256
# ITA    10715
# GER     9830
#        ...
# YMD        5
# SSD        3
# NBO        2
# UNK        2
# NFL        1
# Length: 230, dtype: int64

# %%
df.value_counts('Medal')
# Out:
# Medal
# Gold      13372
# Bronze    13295
# Silver    13116
# dtype: int64
